# %% [markdown]
# # Method Overloading
#
# **Method overloading** ile birden çok method farklı parametrelerle aynı ada sahip olabilir:
#
# <img src = "data:image/png;base64,...">
#
# Farklı türde sayıları toplayan iki methodu olan aşağıdaki örneği ele al:
#
# <img src = "data:image/png;base64,...">
#
# Aynı şeyi yapması gereken iki method tanımlamak yerine, birini overloadlamak daha iyidir.
#
# Aşağıdaki örnekte, <code>PlusMethod</code> methodunu hem <code>int</code> hem de <code>double</code> için çalışacak şekilde overloadlıyoruz:
#
# <img src = "data:image/png;base64,...">
#
# **Note**: Parametrelerin sayısı ve/veya türü farklı olduğu sürece birden çok method aynı ada sahip olabilir.
