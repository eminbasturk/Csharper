# %% [markdown]
# Parametre olarak n tamsayısını ve s stringini kabul eden ve tam olarak n kez tekrarlanan s stringini döndüren bir fonksiyon yaz.

# %% [markdown]
# ### My
#
# <img src = "data:image/png;base64,...">

# %% [markdown]
# ### Best
#
# <img src ="data:image/png;base64,...">
