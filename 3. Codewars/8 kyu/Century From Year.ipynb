# %% [markdown]
# Birinci yüzyıl 1. yıldan 100. yıla (dahil) kadar olan aralığı içerir. İkinci yüzyıl 101'den 200'e kadar olur.
# Sana bir yıl verildi, kaçıncı yüzyıl olduğunu bul.

# %% [markdown]
# ### My
#
# <img src = "data:image/png;base64,...">

# %% [markdown]
# ### Best
#
# <img src = "data:image/png;base64,...">
