# %% [markdown]
# **Bir dizi sayı alırsınız, tüm pozitif olanların toplamını döndürürsünüz.**

# %% [markdown]
# # My Solution
# <img src = "data:image/png;base64,...">

# %% [markdown]
# # Best Practice
#
# <img src = "data:image/png;base64,...">

# %% [markdown]
# * Where methodu direkt array içindekileri filtreliyor.
# * Eleman x olsun, x > 0 olanları Sum() ile topla ve döndür diyor.
