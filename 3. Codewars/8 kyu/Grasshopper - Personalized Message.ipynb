# %% [markdown]
# Kişiselleştirilmiş karşılama veren bir foknsiyon oluştur. Fonksiyon iki parametre alır: name ve owner.
#
# Uygun mesajı döndürmek için koşullu ifadeleri kullan:
#
# name, owner'a eşitse, "Hello boss" döndür. Aksi takdirde, "Hello guest"

# %% [markdown]
# ### My
#
# <img src = "data:image/png;base64,...">
