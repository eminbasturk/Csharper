# %% [markdown]
# Nathan bisiklet sürmeyi seviyor. Nathan susuz kalmaması gerektiğini bildiği için bisiklet sürdüğü her saat başına 0.5 litre su içiyor. Sana saat cinsinden zaman verildi ve senin Nathanın kaç litre su içeceğini bilmen gerekiyor. (En düşük değere yuvarla.)

# %% [markdown]
# ### My
#
# <img src = "data:image/png;base64,...">

# %% [markdown]
# ### Best
#
# <img src = "data:image/png;base64,...">

# %% [markdown]
# Süslü parantez açmadan direkt => ile return edebiliyosun.
