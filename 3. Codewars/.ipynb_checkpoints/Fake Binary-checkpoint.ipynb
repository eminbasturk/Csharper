# %% [markdown]
# Bir rakam stringi veriliyor, 5'in altındaki herhangi bir rakamı '0' ile ve 5 ve üzerindeki herhangi bir rakamı '1' ile değiştir. Oraya çıkan stringi döndür.

# %% [markdown]
# ### My
#
# <img src = "data:image/png;base64,...">

# %% [markdown]
# ### Best
#
# <img src = "data:image/png;base64,...">
