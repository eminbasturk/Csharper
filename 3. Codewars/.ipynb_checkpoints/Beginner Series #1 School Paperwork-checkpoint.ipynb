# %% [markdown]
# Sınıf arkadaşların onlar için biraz evrak kopyası olup olmadığını sordu. Sınıfında n tane sınıf arkadaşın olduğunu ve m sayfa evrak olduğunu biliyorsun.
#
# Görevin kaç tane boş sayfaya ihtiyacın olduğunu hesaplamak. Eğer n veya m 0'dan küçükse 0 döndür.

# %% [markdown]
# ### My  Besttt
#
# <img src = "data:image/png;base64,...">
