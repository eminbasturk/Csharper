# %% [markdown]
# Bir stringde aynı miktarda "x" ve "o" olup olmadığını kontrol et. Method bir bool döndürmeli ve büyük/küçük harfe duyarsız olmalıdır. String herhangi bir karakter içerebilir.

# %% [markdown]
# ### My
#
# <img src = "data:image/png;base64,...">

# %% [markdown]
# ### Best
#
# <img src = "data:image/png;base64,...">
