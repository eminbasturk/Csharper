# %% [markdown]
# Timmy & Saray birbirlerine aşık olduğunu düşünüyor ama yaşadıkları yerde bunu ancak birer çiçek seçtikten sonra anlayacaklardır.
#
# Eğer çiçeklerden biri çift sayıda yapraklı ve diğeri tek sayıda ise aşık oldukları anlamına gelir.
#
# Her bir çiçeğin yaprak sayısını alıp aşıklarsa ture, değillerse yanlış döndüren bir fonksiyon yaz.

# %% [markdown]
# ### My
#
# <img src = "data:image/png;base64,...">

# %% [markdown]
# ### Best
#
# <img src = "data:image/png;base64,...">
