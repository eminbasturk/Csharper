# %% [markdown]
# Girdi olarak bir tamsayı alan ve bu sayının ikili gösteriminde eşit olan bitlerin sayısını döndüren bir fonksiyon yaz. Girişin negatif olmadığını garanti edebilirsin.
#
# Örneğin 1234'ün binary gösterimi 10011010010'dur, dolayısıyla bu durumda fonksiyon 5 döndürmelidir.

# %% [markdown]
# ### My
#
# <img src = "data:image/png;base64,...">

# %% [markdown]
# ### Best
#
# <img src ="data:image/png;base64,...">

# %% [markdown]
# 2lik tabana dönüştürür ve içerisindeki 1'leri sayar.
