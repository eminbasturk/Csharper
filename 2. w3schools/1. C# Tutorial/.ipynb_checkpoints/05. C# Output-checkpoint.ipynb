# %% [markdown]
# # C# Output
#
# C# dilinde değerleri görüntülemek (output almak) veya metni yazdırmak için <code>WriteLine()</code> metodunu kullanabilirsin:
#
# <img src = "data:image/png;base64,...">
#
# İstediğin kadar <code>WriteLine()</code> metodu ekleyebilirsin. Her metot için yeni bir satır ekleyeceğini unutma:
#
# <img src = "data:image/png;base64,...">
#
# Ayrıca sayıların çıktısını alabilir ve matematiksel hesaplamalar yapabilirsin:
#
# <img src = "data:image/png;base64,...">
#
# ## The Write Method
#
# Ayrıca <code>WriteLine</code> metoduna benzer bir <code>Write()</code> metodu da vardır.
#
# Tek fark, çıktının sonuna yeni bir satır eklenmemesidir:
#
# <img src = "data:image/png;base64,...">
#
# Daya iyi okunabilirlik için gerektiğinde (yukarıdaki örnekte "Hello World"'den sonra) fazladan bir boşluk eklemeyi unutma.
#
# Bu tutorialda, kod çıktısını okumayı kolaylaştırdığı için yalnızca <code>WriteLine()</code> kullanılacak.
