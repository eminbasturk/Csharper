# %% [markdown]
# # Break
#
# <code>break</code> daha önce bir <code>switch</code> ifadesinden "atlamak" için kullanıldı.
#
# <code>break</code> ifadesi, bir **döngü**den çıkmak için de kullanılabilir.
#
# Aşağıdaki örnek, <code>i</code>, <code>4</code>'e eşit olduğunda döngüden atlar:
#
# <img src = "data:image/png;base64,...">
#
# # Continue
#
# <code>continue</code> ifadesi, belirtilen bir koşul oluşursa bir iterasyon (döngüde) keser ve döngüdeki bir sonraki iterasyonla devam eder.
#
# Örnek, <code>4</code> değerini atlar:
#
# <img src = "data:image/png;base64,...">
#
# # Break and Continue in While Loop
#
# Ayrıca <code>break</code> ve <code>continue</code> döngülerini while döngülerinde de kullanabilirsiniz:
#
# ## Break Example
#
# <img src = "data:image/png;base64,...">
#
# ## Continue Example
#
# <img src = "data:image/png;base64,...">
