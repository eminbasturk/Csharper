# %% [markdown]
# # C# Math
#
# C# Math classı, sayılar üzerinde matematiksel görevler gerçekleştirmene izin veren birçok metoda sahiptir.
#
# ## Math.Max(x, y)
#
# <code>Math.Max(x, y)</code> metodu, *x* ve *y*'den hangisinin büyük olduğunu bulur:
#
# <img src = "data:image/png;base64,...">
#
# ## Math.Min(x, y)
#
# <code>Math.Min(x, y)</code> metodu, *x* ve *y*'den hangisinin küçük olduğunu bulur:
#
# <img src = "data:image/png;base64,...">
#
# ## Math.Sqrt(x)
#
# <code>Math.Sqrt(x)</code> metodu, *x*'in karekökünü döndürür:
#
# <img src = "data:image/png;base64,...">
#
# ## Math.Abs(x)
#
# <code>Math.Abs(x)</code> metodu, x'in mutlak (pozitif) değerini döndürür:
#
# <img src = "data:image/png;base64,...">
#
# ## Math.Round(x)
#
# <code>Math.Round(x)</code> metodu, x'i en yakın tam sayıya yuvarlar:
#
# <img src = "data:image/png;base64,...">
