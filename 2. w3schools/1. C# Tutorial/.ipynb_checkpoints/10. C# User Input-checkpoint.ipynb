# %% [markdown]
# # Get User Input
#
# Değerlerin çıktısını almak (yazdırmak) için <code>Console.WriteLine()</code> kullanıldığını zaten öğrendin. Şimdi kullanıcı girdisi almak için <code>Console.ReadLine()</code>'ı kullanacaksın.
#
# Aşağıdaki örnekte kullanıcı, <code>userName</code> değişkeninde depolanan kendi kullanıcı adını girebilir. Ardından <code>userName</code> değeri yazdırılabilir:
#
# <img src = "data:image/png;base64,...">
#
# ## User Input and Numbers
#
# <code>Console.ReadLine()</code> metodu bir <code>string</code> döndürür. Bu nedenle <code>int</code> gibi başka bir veri türünden bilgi alamazsın. Aşağıdaki program bir hataya neden olur:
#
# <img src = "data:image/png;base64,...">
#
# Hata mesajının dediği gibi, 'string' tipini dolaylı olarak 'int'e dönüştüremezsin.
#
# Neyse ki, bir önceki bölümde (Type Casting), <code>Convert.To</code> metotlarından birini kullanarak herhangi bir türü açıkça dönüştürebileceğini öğrendin:
#
# <img src = "data:image/png;base64,...">
#
# **Note**: Yanlış girdi girersen (örneğin, sayısal bir girdideki metin), bir istisna/hata mesajı alırsın (System.FormatException gibi: 'Giriş dizesi doğru biçimde değildi.').
#
# Sonraki bir bölümde istisnalar (exceptions) ve hataların nasıl ele alınacağı hakkında daha fazla bilgi edineceksin.
